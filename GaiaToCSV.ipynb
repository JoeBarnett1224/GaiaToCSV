# %%
from astropy.coordinates import SkyCoord
import astropy.units as u
from astroquery.gaia import Gaia
import tkinter as tk

def csv():
    global window2
    window2 = tk.Toplevel()
    window2.title("Confirmation_Box")
    
    RA = str(RA_int.get())
    Dec = str(Dec_int.get())
    r = str(r_int.get())
    coord = SkyCoord(ra = RA, dec = Dec, unit = (u.degree, u.degree))
    Radius = u.Quantity(r, u.deg)
    
    Gaia.ROW_LIMIT = -1
    t = Gaia.query_object(coord, radius = Radius, columns = ["source_id"])
    rows = str(len(t))
    
    window2_label = tk.Label(window2,
                             text = "This table contains " + rows +
                             " rows. Do you want to continue?", font = "Calibri 14")
    
    window2_label.pack()
    button_frame = tk.Frame(window2)
    button_frame.pack()
    yes_button = tk.Button(button_frame, text = "Yes", command = yes)
    yes_button.pack(side = "left")
    no_button = tk.Button(button_frame, text = "No", command = no)
    no_button.pack(side = "left")

def yes():
    RA = str(RA_int.get())
    Dec = str(Dec_int.get())
    r = str(r_int.get())
    coord = SkyCoord(ra = RA, dec = Dec, unit = (u.degree, u.degree))
    Radius = u.Quantity(r, u.deg)
    
    check_list = []
    
    if solution_id_checkbox_var.get() == 1:
        check_list.append("solution_id")
        
    if designation_checkbox_var.get() == 1:
        check_list.append("designation")

    if source_id_checkbox_var.get() == 1:
        check_list.append("source_id")
        
    if random_index_checkbox_var.get() == 1:
        check_list.append("random_index")
        
    if ref_epoch_checkbox_var.get() == 1:
        check_list.append("ref_epoch")
        
    if ra_checkbox_var.get() == 1:
        check_list.append("ra")
        
    if ra_error_checkbox_var.get() == 1:
        check_list.append("ra_error")
        
    if dec_checkbox_var.get() == 1:
        check_list.append("dec")
        
    if dec_error_checkbox_var.get() == 1:
        check_list.append("dec_error")
        
    if parallax_checkbox_var.get() == 1:
        check_list.append("parallax")
        
    if parallax_error_checkbox_var.get() == 1:
        check_list.append("parallax_error")
        
    if parallax_over_error_checkbox_var.get() == 1:
        check_list.append("parallax_over_error")
        
    if pmra_checkbox_var.get() == 1:
        check_list.append("pmra")

    if pmra_error_checkbox_var.get() == 1:
        check_list.append("pmra_error")
        
    if pmdec_checkbox_var.get() == 1:
        check_list.append("pmdec")

    if pmdec_error_checkbox_var.get() == 1:
        check_list.append("pmdec_error")

    if ra_dec_corr_checkbox_var.get() == 1:
        check_list.append("ra_dec_corr")

    if ra_parallax_corr_checkbox_var.get() == 1:
        check_list.append("ra_parallax_corr")

    if ra_pmra_corr_checkbox_var.get() == 1:
        check_list.append("ra_pmra_corr")

    if ra_pmdec_corr_checkbox_var.get() == 1:
        check_list.append("ra_pmdec_corr")

    if dec_parallax_corr_checkbox_var.get() == 1:
        check_list.append("dec_parallax_corr")

    if dec_pmra_corr_checkbox_var.get() == 1:
        check_list.append("dec_pmra_corr")

    if dec_pmdec_corr_checkbox_var.get() == 1:
        check_list.append("dec_pmdec_corr")

    if parallax_pmra_corr_checkbox_var.get() == 1:
        check_list.append("parallax_pmra_corr")

    if parallax_pmdec_corr_checkbox_var.get() == 1:
        check_list.append("parallax_pmdec_corr")

    if pmra_pmdec_corr_checkbox_var.get() == 1:
        check_list.append("pmra_pmdec_corr")

    if astrometric_n_obs_al_checkbox_var.get() == 1:
        check_list.append("astrometric_n_obs_al")

    if astrometric_n_obs_ac_checkbox_var.get() == 1:
        check_list.append("astrometric_n_obs_ac")

    if astrometric_n_good_obs_al_checkbox_var.get() == 1:
        check_list.append("astrometric_n_good_obs_al")

    if astrometric_n_bad_obs_al_checkbox_var.get() == 1:
        check_list.append("astrometric_n_bad_obs_al")

    if astrometric_gof_al_checkbox_var.get() == 1:
        check_list.append("astrometric_gof_al")

    if astrometric_chi2_al_checkbox_var.get() == 1:
        check_list.append("astrometric_chi2_al")

    if astrometric_excess_noise_checkbox_var.get() == 1:
        check_list.append("astrometric_excess_noise")

    if astrometric_excess_noise_sig_checkbox_var.get() == 1:
        check_list.append("astrometric_excess_noise_sig")

    if astrometric_params_solved_checkbox_var.get() == 1:
        check_list.append("astrometric_params_solved")

    if astrometric_primary_flag_checkbox_var.get() == 1:
        check_list.append("astrometric_primary_flag")

    if visibility_periods_used_checkbox_var.get() == 1:
        check_list.append("visibility_periods_used")

    if astrometric_sigma5d_max_checkbox_var.get() == 1:
        check_list.append("astrometric_sigma5d_max")

    if duplicated_source_checkbox_var.get() == 1:
        check_list.append("duplicated_source")

    if phot_g_n_obs_checkbox_var.get() == 1:
        check_list.append("phot_g_n_obs")

    if phot_g_mean_flux_checkbox_var.get() == 1:
        check_list.append("phot_g_mean_flux")

    if phot_g_mean_flux_error_checkbox_var.get() == 1:
        check_list.append("phot_g_mean_flux_error")

    if phot_g_mean_flux_over_error_checkbox_var.get() == 1:
        check_list.append("phot_g_mean_flux_over_error")

    if phot_g_mean_mag_checkbox_var.get() == 1:
        check_list.append("phot_g_mean_mag")

    if phot_bp_n_obs_checkbox_var.get() == 1:
        check_list.append("phot_bp_n_obs")

    if phot_bp_mean_flux_checkbox_var.get() == 1:
        check_list.append("phot_bp_mean_flux")

    if phot_bp_mean_flux_error_checkbox_var.get() == 1:
        check_list.append("phot_bp_mean_flux_error")

    if phot_bp_mean_flux_over_error_checkbox_var.get() == 1:
        check_list.append("phot_bp_mean_flux_over_error")

    if phot_bp_mean_mag_checkbox_var.get() == 1:
        check_list.append("phot_bp_mean_mag")

    if phot_rp_n_obs_checkbox_var.get() == 1:
        check_list.append("phot_rp_n_obs")

    if phot_rp_mean_flux_checkbox_var.get() == 1:
        check_list.append("phot_rp_mean_flux")

    if phot_rp_mean_flux_error_checkbox_var.get() == 1:
        check_list.append("phot_rp_mean_flux_error")

    if phot_rp_mean_flux_over_error_checkbox_var.get() == 1:
        check_list.append("phot_rp_mean_flux_over_error")

    if phot_rp_mean_mag_checkbox_var.get() == 1:
        check_list.append("phot_rp_mean_mag")

    if phot_bp_rp_excess_factor_checkbox_var.get() == 1:
        check_list.append("phot_bp_rp_excess_factor")

    if phot_proc_mode_checkbox_var.get() == 1:
        check_list.append("phot_proc_mode")

    if bp_rp_checkbox_var.get() == 1:
        check_list.append("bp_rp")

    if bp_g_checkbox_var.get() == 1:
        check_list.append("bp_g")

    if g_rp_checkbox_var.get() == 1:
        check_list.append("g_rp")

    if radial_velocity_checkbox_var.get() == 1:
        check_list.append("radial_velocity")

    if radial_velocity_error_checkbox_var.get() == 1:
        check_list.append("radial_velocity_error")

    if rv_nb_transits_checkbox_var.get() == 1:
        check_list.append("rv_nb_transits")

    if rv_template_teff_checkbox_var.get() == 1:
        check_list.append("rv_template_teff")

    if rv_template_logg_checkbox_var.get() == 1:
        check_list.append("rv_template_logg")

    if rv_template_fe_h_checkbox_var.get() == 1:
        check_list.append("rv_template_fe_h")

    if phot_variable_flag_checkbox_var.get() == 1:
        check_list.append("phot_variable_flag")

    if l_checkbox_var.get() == 1:
        check_list.append("l")

    if b_checkbox_var.get() == 1:
        check_list.append("b")

    if ecl_lon_checkbox_var.get() == 1:
        check_list.append("ecl_lon")

    if ecl_lat_checkbox_var.get() == 1:
        check_list.append("ecl_lat")
        
    Fn = str(file_name_int.get())
    if Fn != "":
        Gaia.ROW_LIMIT = -1
        job = Gaia.cone_search(coord, radius = Radius, columns = check_list, dump_to_file = True,
                           output_file = Fn, output_format = "csv")
    else:
        Gaia.ROW_LIMIT = -1
        job = Gaia.cone_search(coord, radius = Radius, columns = check_list, dump_to_file = True,
                           output_format = "csv")
    
    window2.destroy()
    
def no():
    window2.destroy()
    
def help1():
    global window3
    window3 = tk.Toplevel()
    window3.title("Help")
    window3.geometry("1250x500")
    help_string = """Note: In order for the code to run the following packages must be installed by entering the pip install command in the terminal: tkinter, astroquery,
    numpy, astropy, pyvo, requests, keyring, Beautiful Soup, html5lib, curl, pytest-astropy, and pytest-rerunfailures.

    To begin a search, input the right ascension, declination, and radius in the corresponding entry fields at the top of the app. Units should be in degrees.

    Next, check the boxes for the columns to be displayed in the CSV file. For information on which data appears in each column see the Gaia Documentation
    at https://gea.esac.esa.int/archive/documentation/GDR2/Gaia_archive/chap_datamodel/sec_dm_main_tables/ssec_dm_gaia_source.html.

    Lastly, input a file name in the optional entry field at the bottom and click "Download CSV". This will open a dialogue box telling how much data the
    output file will contain. To continue click "Yes" and the file will be saved in the directory this program is saved to. The Dialogue box will close once
    the download is complete. To refine the search, click "No" to close the dialogue box. No file will be downloaded in this case."""
    help_label = tk.Label(window3, text = help_string, font = "Calibri 14")
    help_label.pack()
    help_window_button = tk.Button(window3, text = "Close", command = close1)
    help_window_button.pack()
    
def close1():
    window3.destroy()
    
def acknowledgement():
    global window4
    window4 = tk.Toplevel()
    window4.title("Acknowledgements")
    window4.geometry("800x500")
    acknowledgement_string = """I acknowledge the extensive use of the Gaia Archive for this
    project and am grateful for the work done by the European Space Agency for its work on the Gaia
    Mission.

    Furthermore, I would like to thank the creators of the astropy and astroquery packages. Both
    were valuable in using Python to access the Gaia Archive.

    I thank the owner of the YouTube channel Clear Code. His tkinter tutorial helped me learn how
    to create user interfaces in Python. Including the one for this project.

    I thank Dr. Chris Sneden and Dr. Kurtis Williams for supervising my research. They helped me
    gain experience using the Gaia Archive. I further thank Dr. Williams for giving me the idea for
    this project."""
    acknowledgement_label = tk.Label(window4, text = acknowledgement_string, font = "Calibri 14")
    acknowledgement_label.pack()
    acknowledgement_window_button = tk.Button(window4, text = "Close", command = close2)
    acknowledgement_window_button.pack()
    
def close2():
    window4.destroy()

#Create Window

window = tk.Tk()
window.title("Gaia to CSV")
window.state("zoomed")

#Title

title_label = tk.Label(window, text = "Gaia to CSV", font = "Calibri 24 bold")
title_label.pack()

#Frames

frame1 = tk.Frame(window)
frame1.pack()
frame2 = tk.Frame(window)
frame2.pack()
frame3 = tk.Frame(window)
frame3.pack()
frame4 = tk.Frame(window)
frame4.pack()
frame5 = tk.Frame(window)
frame5.pack()
frame6 = tk.Frame(window)
frame6.pack()
frame7 = tk.Frame(window)
frame7.pack()
frame8 = tk.Frame(window)
frame8.pack()
frame9 = tk.Frame(window)
frame9.pack()
frame10 = tk.Frame(window)
frame10.pack()
frame11 = tk.Frame(window)
frame11.pack()
frame12 = tk.Frame(window)
frame12.pack()
frame13 = tk.Frame(window)
frame13.pack()
frame14 = tk.Frame(window)
frame14.pack()
frame15 = tk.Frame(window)
frame15.pack()
frame16 = tk.Frame(window)
frame16.pack()

#Entry Fields

RA_label = tk.Label(frame1, text = "Right Ascension (degrees):", font = "Calibri 16")
RA_int = tk.DoubleVar()
RA = tk.Entry(frame1, textvariable = RA_int)
Dec_label = tk.Label(frame1, text = "Declination (degrees):", font = "Calibri 16")
Dec_int = tk.DoubleVar()
Dec = tk.Entry(frame1, textvariable = Dec_int)
r_label = tk.Label(frame1, text = "Radius (degrees):", font = "Calibri 16")
r_int = tk.DoubleVar()
r = tk.Entry(frame1, textvariable = r_int)
RA_label.pack(side = "left")
RA.pack(side = "left")
Dec_label.pack(side = "left")
Dec.pack(side = "left")
r_label.pack(side = "left")
r.pack(side = "left")

#checkboxes

solution_id_checkbox_var = tk.IntVar()
solution_id_checkbox = tk.Checkbutton(frame2, text = "solution_id", font = "Calibri 12", 
                                      variable = solution_id_checkbox_var)
solution_id_checkbox.pack(side = "left")

designation_checkbox_var = tk.IntVar()
designation_checkbox = tk.Checkbutton(frame2, text = "designation", font = "Calibri 12",
                                      variable = designation_checkbox_var)
designation_checkbox.pack(side = "left")

source_id_checkbox_var = tk.IntVar(value = 1)
source_id_checkbox = tk.Checkbutton(frame2, text = "source_id", font = "Calibri 12",
                                      variable = source_id_checkbox_var)
source_id_checkbox.pack(side = "left")

random_index_checkbox_var = tk.IntVar()
random_index_checkbox = tk.Checkbutton(frame2, text = "random_index", font = "Calibri 12",
                                      variable = random_index_checkbox_var)
random_index_checkbox.pack(side = "left")

ref_epoch_checkbox_var = tk.IntVar()
ref_epoch_checkbox = tk.Checkbutton(frame2, text = "ref_epoch", font = "Calibri 12",
                                      variable = ref_epoch_checkbox_var)
ref_epoch_checkbox.pack(side = "left")

ra_checkbox_var = tk.IntVar(value = 1)
ra_checkbox = tk.Checkbutton(frame3, text = "ra",  font = "Calibri 12",
                                      variable = ra_checkbox_var)
ra_checkbox.pack(side = "left")

ra_error_checkbox_var = tk.IntVar()
ra_error_checkbox = tk.Checkbutton(frame3, text = "ra_error", font = "Calibri 12",
                                      variable = ra_error_checkbox_var)
ra_error_checkbox.pack(side = "left")

dec_checkbox_var = tk.IntVar(value = 1)
dec_checkbox = tk.Checkbutton(frame3, text = "dec", font = "Calibri 12",
                                      variable = dec_checkbox_var)
dec_checkbox.pack(side = "left")

dec_error_checkbox_var = tk.IntVar()
dec_error_checkbox = tk.Checkbutton(frame3, text = "dec_error", font = "Calibri 12",
                                      variable = dec_error_checkbox_var)
dec_error_checkbox.pack(side = "left")

parallax_checkbox_var = tk.IntVar(value = 1)
parallax_checkbox = tk.Checkbutton(frame3, text = "parallax", font = "Calibri 12",
                                      variable = parallax_checkbox_var)
parallax_checkbox.pack(side = "left")

parallax_error_checkbox_var = tk.IntVar()
parallax_error_checkbox = tk.Checkbutton(frame4, text = "parallax_error", font = "Calibri 12",
                                      variable = parallax_error_checkbox_var)
parallax_error_checkbox.pack(side = "left")

parallax_over_error_checkbox_var = tk.IntVar()
parallax_over_error_checkbox = tk.Checkbutton(frame4, text = "parallax_over_error",
                                      font = "Calibri 12",
                                      variable = parallax_over_error_checkbox_var)
parallax_over_error_checkbox.pack(side = "left")

pmra_checkbox_var = tk.IntVar(value = 1)
pmra_checkbox = tk.Checkbutton(frame4, text = "pmra", font = "Calibri 12",
                                      variable = pmra_checkbox_var)
pmra_checkbox.pack(side = "left")

pmra_error_checkbox_var = tk.IntVar()
pmra_error_checkbox = tk.Checkbutton(frame4, text = "pmra_error", font = "Calibri 12",
                                      variable = pmra_error_checkbox_var)
pmra_error_checkbox.pack(side = "left")

pmdec_checkbox_var = tk.IntVar(value = 1)
pmdec_checkbox = tk.Checkbutton(frame4, text = "pmdec", font = "Calibri 12",
                                      variable = pmdec_checkbox_var)
pmdec_checkbox.pack(side = "left")

pmdec_error_checkbox_var = tk.IntVar()
pmdec_error_checkbox = tk.Checkbutton(frame5, text = "pmdec_error", font = "Calibri 12",
                                      variable = pmdec_error_checkbox_var)
pmdec_error_checkbox.pack(side = "left")

ra_dec_corr_checkbox_var = tk.IntVar()
ra_dec_corr_checkbox = tk.Checkbutton(frame5, text = "ra_dec_corr", font = "Calibri 12",
                                      variable = ra_dec_corr_checkbox_var)
ra_dec_corr_checkbox.pack(side = "left")

ra_parallax_corr_checkbox_var = tk.IntVar()
ra_parallax_corr_checkbox = tk.Checkbutton(frame5, text = "ra_parallax_corr", font = "Calibri 12",
                                      variable = ra_parallax_corr_checkbox_var)
ra_parallax_corr_checkbox.pack(side = "left")

ra_pmra_corr_checkbox_var = tk.IntVar()
ra_pmra_corr_checkbox = tk.Checkbutton(frame5, text = "ra_pmra_corr", font = "Calibri 12",
                                      variable = ra_pmra_corr_checkbox_var)
ra_pmra_corr_checkbox.pack(side = "left")

ra_pmdec_corr_checkbox_var = tk.IntVar()
ra_pmdec_corr_checkbox = tk.Checkbutton(frame5, text = "ra_pmdec_corr", font = "Calibri 12",
                                      variable = ra_pmdec_corr_checkbox_var)
ra_pmdec_corr_checkbox.pack(side = "left")

dec_parallax_corr_checkbox_var = tk.IntVar()
dec_parallax_corr_checkbox = tk.Checkbutton(frame6, text = "dec_parallax_corr",
                                      font = "Calibri 12",
                                      variable = dec_parallax_corr_checkbox_var)
dec_parallax_corr_checkbox.pack(side = "left")

dec_pmra_corr_checkbox_var = tk.IntVar()
dec_pmra_corr_checkbox = tk.Checkbutton(frame6, text = "dec_pmra_corr", font = "Calibri 12",
                                      variable = dec_pmra_corr_checkbox_var)
dec_pmra_corr_checkbox.pack(side = "left")

dec_pmdec_corr_checkbox_var = tk.IntVar()
dec_pmdec_corr_checkbox = tk.Checkbutton(frame6, text = "dec_pmdec_corr", font = "Calibri 12",
                                      variable = dec_pmdec_corr_checkbox_var)
dec_pmdec_corr_checkbox.pack(side = "left")

parallax_pmra_corr_checkbox_var = tk.IntVar()
parallax_pmra_corr_checkbox = tk.Checkbutton(frame6, text = "parallax_pmra_corr",
                                      font = "Calibri 12",
                                      variable = parallax_pmra_corr_checkbox_var)
parallax_pmra_corr_checkbox.pack(side = "left")

parallax_pmdec_corr_checkbox_var = tk.IntVar()
parallax_pmdec_corr_checkbox = tk.Checkbutton(frame6, text = "parallax_pmdec_corr",
                                      font = "Calibri 12",
                                      variable = parallax_pmdec_corr_checkbox_var)
parallax_pmdec_corr_checkbox.pack(side = "left")

pmra_pmdec_corr_checkbox_var = tk.IntVar()
pmra_pmdec_corr_checkbox = tk.Checkbutton(frame7, text = "pmra_pmdec_corr",  font = "Calibri 12",
                                      variable = pmra_pmdec_corr_checkbox_var)
pmra_pmdec_corr_checkbox.pack(side = "left")

astrometric_n_obs_al_checkbox_var = tk.IntVar()
astrometric_n_obs_al_checkbox = tk.Checkbutton(frame7, text = "astrometric_n_obs_al",
                                      font = "Calibri 12",
                                      variable = astrometric_n_obs_al_checkbox_var)
astrometric_n_obs_al_checkbox.pack(side = "left")

astrometric_n_obs_ac_checkbox_var = tk.IntVar()
astrometric_n_obs_ac_checkbox = tk.Checkbutton(frame7, text = "astrometric_n_obs_ac",
                                      font = "Calibri 12",
                                      variable = astrometric_n_obs_ac_checkbox_var)
astrometric_n_obs_ac_checkbox.pack(side = "left")

astrometric_n_good_obs_al_checkbox_var = tk.IntVar()
astrometric_n_good_obs_al_checkbox = tk.Checkbutton(frame7, text = "astrometric_n_good_obs_al",
                                      font = "Calibri 12",
                                      variable = astrometric_n_good_obs_al_checkbox_var)
astrometric_n_good_obs_al_checkbox.pack(side = "left")

astrometric_n_bad_obs_al_checkbox_var = tk.IntVar()
astrometric_n_bad_obs_al_checkbox = tk.Checkbutton(frame7, text = "astrometric_n_bad_obs_al",
                                      font = "Calibri 12",
                                      variable = astrometric_n_bad_obs_al_checkbox_var)
astrometric_n_bad_obs_al_checkbox.pack(side = "left")

astrometric_gof_al_checkbox_var = tk.IntVar()
astrometric_gof_al_checkbox = tk.Checkbutton(frame8, text = "astrometric_gof_al",
                                      font = "Calibri 12",
                                      variable = astrometric_gof_al_checkbox_var)
astrometric_gof_al_checkbox.pack(side = "left")

astrometric_chi2_al_checkbox_var = tk.IntVar()
astrometric_chi2_al_checkbox = tk.Checkbutton(frame8, text = "astrometric_chi2_al",
                                      font = "Calibri 12",
                                      variable = astrometric_chi2_al_checkbox_var)
astrometric_chi2_al_checkbox.pack(side = "left")

astrometric_excess_noise_checkbox_var = tk.IntVar()
astrometric_excess_noise_checkbox = tk.Checkbutton(frame8, text = "astrometric_excess_noise",
                                      font = "Calibri 12",
                                      variable = astrometric_excess_noise_checkbox_var)
astrometric_excess_noise_checkbox.pack(side = "left")

astrometric_excess_noise_sig_checkbox_var = tk.IntVar()
astrometric_excess_noise_sig_checkbox = tk.Checkbutton(frame8,
                                      text = "astrometric_excess_noise_sig", font = "Calibri 12",
                                      variable = astrometric_excess_noise_sig_checkbox_var)
astrometric_excess_noise_sig_checkbox.pack(side = "left")

astrometric_params_solved_checkbox_var = tk.IntVar()
astrometric_params_solved_checkbox = tk.Checkbutton(frame8, text = "astrometric_params_solved",
                                      font = "Calibri 12",
                                      variable = astrometric_params_solved_checkbox_var)
astrometric_params_solved_checkbox.pack(side = "left")

astrometric_primary_flag_checkbox_var = tk.IntVar()
astrometric_primary_flag_checkbox = tk.Checkbutton(frame9, text = "astrometric_primary_flag",
                                      font = "Calibri 12",
                                      variable = astrometric_primary_flag_checkbox_var)
astrometric_primary_flag_checkbox.pack(side = "left")

visibility_periods_used_checkbox_var = tk.IntVar()
visibility_periods_used_checkbox = tk.Checkbutton(frame9, text = "visibility_periods_used",
                                      font = "Calibri 12",
                                      variable = visibility_periods_used_checkbox_var)
visibility_periods_used_checkbox.pack(side = "left")

astrometric_sigma5d_max_checkbox_var = tk.IntVar()
astrometric_sigma5d_max_checkbox = tk.Checkbutton(frame9, text = "astrometric_sigma5d_max",
                                      font = "Calibri 12",
                                      variable = astrometric_sigma5d_max_checkbox_var)
astrometric_sigma5d_max_checkbox.pack(side = "left")

duplicated_source_checkbox_var = tk.IntVar()
duplicated_source_checkbox = tk.Checkbutton(frame9, text = "duplicated_source",
                                      font = "Calibri 12",
                                      variable = duplicated_source_checkbox_var)
duplicated_source_checkbox.pack(side = "left")

phot_g_n_obs_checkbox_var = tk.IntVar()
phot_g_n_obs_checkbox = tk.Checkbutton(frame9, text = "phot_g_n_obs", font = "Calibri 12",
                                      variable = phot_g_n_obs_checkbox_var)
phot_g_n_obs_checkbox.pack(side = "left")

phot_g_mean_flux_checkbox_var = tk.IntVar()
phot_g_mean_flux_checkbox = tk.Checkbutton(frame10, text = "phot_g_mean_flux", font = "Calibri 12",
                                      variable = phot_g_mean_flux_checkbox_var)
phot_g_mean_flux_checkbox.pack(side = "left")

phot_g_mean_flux_error_checkbox_var = tk.IntVar()
phot_g_mean_flux_error_checkbox = tk.Checkbutton(frame10, text = "phot_g_mean_flux_error",
                                      font = "Calibri 12",
                                      variable = phot_g_mean_flux_error_checkbox_var)
phot_g_mean_flux_error_checkbox.pack(side = "left")

phot_g_mean_flux_over_error_checkbox_var = tk.IntVar()
phot_g_mean_flux_over_error_checkbox = tk.Checkbutton(frame10,
                                      text = "phot_g_mean_flux_over_error", font = "Calibri 12",
                                      variable = phot_g_mean_flux_over_error_checkbox_var)
phot_g_mean_flux_over_error_checkbox.pack(side = "left")

phot_g_mean_mag_checkbox_var = tk.IntVar(value = 1)
phot_g_mean_mag_checkbox = tk.Checkbutton(frame10, text = "phot_g_mean_mag", font = "Calibri 12",
                                      variable = phot_g_mean_mag_checkbox_var)
phot_g_mean_mag_checkbox.pack(side = "left")

phot_bp_n_obs_checkbox_var = tk.IntVar()
phot_bp_n_obs_checkbox = tk.Checkbutton(frame10, text = "phot_bp_n_obs", font = "Calibri 12",
                                      variable = phot_bp_n_obs_checkbox_var)
phot_bp_n_obs_checkbox.pack(side = "left")

phot_bp_mean_flux_checkbox_var = tk.IntVar()
phot_bp_mean_flux_checkbox = tk.Checkbutton(frame11, text = "phot_bp_mean_flux",
                                      font = "Calibri 12",
                                      variable = phot_bp_mean_flux_checkbox_var)
phot_bp_mean_flux_checkbox.pack(side = "left")

phot_bp_mean_flux_error_checkbox_var = tk.IntVar()
phot_bp_mean_flux_error_checkbox = tk.Checkbutton(frame11, text = "phot_bp_mean_flux_error",
                                      font = "Calibri 12",
                                      variable = phot_bp_mean_flux_error_checkbox_var)
phot_bp_mean_flux_error_checkbox.pack(side = "left")

phot_bp_mean_flux_over_error_checkbox_var = tk.IntVar()
phot_bp_mean_flux_over_error_checkbox = tk.Checkbutton(frame11,
                                      text = "phot_bp_mean_flux_over_error", font = "Calibri 12",
                                      variable = phot_bp_mean_flux_over_error_checkbox_var)
phot_bp_mean_flux_over_error_checkbox.pack(side = "left")

phot_bp_mean_mag_checkbox_var = tk.IntVar()
phot_bp_mean_mag_checkbox = tk.Checkbutton(frame11, text = "phot_bp_mean_mag", font = "Calibri 12",
                                      variable = phot_bp_mean_mag_checkbox_var)
phot_bp_mean_mag_checkbox.pack(side = "left")

phot_rp_n_obs_checkbox_var = tk.IntVar()
phot_rp_n_obs_checkbox = tk.Checkbutton(frame11, text = "phot_rp_n_obs", font = "Calibri 12",
                                      variable = phot_rp_n_obs_checkbox_var)
phot_rp_n_obs_checkbox.pack(side = "left")

phot_rp_mean_flux_checkbox_var = tk.IntVar()
phot_rp_mean_flux_checkbox = tk.Checkbutton(frame12, text = "phot_rp_mean_flux",
                                      font = "Calibri 12",
                                      variable = phot_rp_mean_flux_checkbox_var)
phot_rp_mean_flux_checkbox.pack(side = "left")

phot_rp_mean_flux_error_checkbox_var = tk.IntVar()
phot_rp_mean_flux_error_checkbox = tk.Checkbutton(frame12, text = "phot_rp_mean_flux_error",
                                      font = "Calibri 12",
                                      variable = phot_rp_mean_flux_error_checkbox_var)
phot_rp_mean_flux_error_checkbox.pack(side = "left")

phot_rp_mean_flux_over_error_checkbox_var = tk.IntVar()
phot_rp_mean_flux_over_error_checkbox = tk.Checkbutton(frame12,
                                      text = "phot_rp_mean_flux_over_error", font = "Calibri 12",
                                      variable = phot_rp_mean_flux_over_error_checkbox_var)
phot_rp_mean_flux_over_error_checkbox.pack(side = "left")

phot_rp_mean_mag_checkbox_var = tk.IntVar()
phot_rp_mean_mag_checkbox = tk.Checkbutton(frame12, text = "phot_rp_mean_mag", font = "Calibri 12",
                                      variable = phot_rp_mean_mag_checkbox_var)
phot_rp_mean_mag_checkbox.pack(side = "left")

phot_bp_rp_excess_factor_checkbox_var = tk.IntVar()
phot_bp_rp_excess_factor_checkbox = tk.Checkbutton(frame12, text = "phot_bp_rp_excess_factor",
                                      font = "Calibri 12",
                                      variable = phot_bp_rp_excess_factor_checkbox_var)
phot_bp_rp_excess_factor_checkbox.pack(side = "left")

phot_proc_mode_checkbox_var = tk.IntVar()
phot_proc_mode_checkbox = tk.Checkbutton(frame13, text = "phot_proc_mode", font = "Calibri 12",
                                      variable = phot_proc_mode_checkbox_var)
phot_proc_mode_checkbox.pack(side = "left")

bp_rp_checkbox_var = tk.IntVar(value = 1)
bp_rp_checkbox = tk.Checkbutton(frame13, text = "bp_rp", font = "Calibri 12",
                                      variable = bp_rp_checkbox_var)
bp_rp_checkbox.pack(side = "left")

bp_g_checkbox_var = tk.IntVar()
bp_g_checkbox = tk.Checkbutton(frame13, text = "bp_g", font = "Calibri 12",
                                      variable = bp_g_checkbox_var)
bp_g_checkbox.pack(side = "left")

g_rp_checkbox_var = tk.IntVar()
g_rp_checkbox = tk.Checkbutton(frame13, text = "g_rp", font = "Calibri 12",
                                      variable = g_rp_checkbox_var)
g_rp_checkbox.pack(side = "left")

radial_velocity_checkbox_var = tk.IntVar(value = 1)
radial_velocity_checkbox = tk.Checkbutton(frame13, text = "radial_velocity", font = "Calibri 12",
                                      variable = radial_velocity_checkbox_var)
radial_velocity_checkbox.pack(side = "left")

radial_velocity_error_checkbox_var = tk.IntVar()
radial_velocity_error_checkbox = tk.Checkbutton(frame14, text = "radial_velocity_error",
                                      font = "Calibri 12",
                                      variable = radial_velocity_error_checkbox_var)
radial_velocity_error_checkbox.pack(side = "left")

rv_nb_transits_checkbox_var = tk.IntVar()
rv_nb_transits_checkbox = tk.Checkbutton(frame14, text = "rv_nb_transits", font = "Calibri 12",
                                      variable = rv_nb_transits_checkbox_var)
rv_nb_transits_checkbox.pack(side = "left")

rv_template_teff_checkbox_var = tk.IntVar()
rv_template_teff_checkbox = tk.Checkbutton(frame14, text = "rv_template_teff", font = "Calibri 12",
                                      variable = rv_template_teff_checkbox_var)
rv_template_teff_checkbox.pack(side = "left")

rv_template_logg_checkbox_var = tk.IntVar()
rv_template_logg_checkbox = tk.Checkbutton(frame14, text = "rv_template_logg", font = "Calibri 12",
                                      variable = rv_template_logg_checkbox_var)
rv_template_logg_checkbox.pack(side = "left")

rv_template_fe_h_checkbox_var = tk.IntVar()
rv_template_fe_h_checkbox = tk.Checkbutton(frame14, text = "rv_template_fe_h", font = "Calibri 12",
                                      variable = rv_template_fe_h_checkbox_var)
rv_template_fe_h_checkbox.pack(side = "left")

phot_variable_flag_checkbox_var = tk.IntVar(value = 1)
phot_variable_flag_checkbox = tk.Checkbutton(frame15, text = "phot_variable_flag",
                                      font = "Calibri 12",
                                      variable = phot_variable_flag_checkbox_var)
phot_variable_flag_checkbox.pack(side = "left")

l_checkbox_var = tk.IntVar()
l_checkbox = tk.Checkbutton(frame15, text = "l", font = "Calibri 12",
                                      variable = l_checkbox_var)
l_checkbox.pack(side = "left")

b_checkbox_var = tk.IntVar()
b_checkbox = tk.Checkbutton(frame15, text = "b", font = "Calibri 12",
                                      variable = b_checkbox_var)
b_checkbox.pack(side = "left")

ecl_lon_checkbox_var = tk.IntVar()
ecl_lon_checkbox = tk.Checkbutton(frame15, text = "ecl_lon", font = "Calibri 12",
                                      variable = ecl_lon_checkbox_var)
ecl_lon_checkbox.pack(side = "left")

ecl_lat_checkbox_var = tk.IntVar()
ecl_lat_checkbox = tk.Checkbutton(frame15, text = "ecl_lat", font = "Calibri 12",
                                      variable = ecl_lat_checkbox_var)
ecl_lat_checkbox.pack(side = "left")

#button

file_label = tk.Label(frame16, text = "File name:", font = "Calibri 16")
file_label.pack(side = "left")
file_name_int = tk.StringVar()
file_name = tk.Entry(frame16, textvariable = file_name_int)
file_name.pack(side = "left")
button = tk.Button(frame16, text = "Download CSV", command = csv)
button.pack(side = "left")

#signature

signature_frame = tk.Frame(window)
signature_frame.pack(side = "bottom")
signature_label = tk.Label(signature_frame, text = "Created by Joseph W Barnett",
                           font = "Calibri 10")
signature_label.pack()

#Help & Acknowledgements
bottom_frame = tk.Frame(window)
bottom_frame.pack(side = "bottom", fill = "x")

help_button = tk.Button(bottom_frame, text = "Help", command = help1)
help_button.pack(side = "left")

acknowledgement_button = tk.Button(bottom_frame, text = "Acknowledgements",
                                   command = acknowledgement)
acknowledgement_button.pack(side = "right")

#run

window.mainloop()
